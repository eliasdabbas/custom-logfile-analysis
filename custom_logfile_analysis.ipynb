# %% [raw]
# ---
# format:
#   html:
#     theme: cosmo
#     embed-resources: true
#     code-fold: false
#     grid:
#         body-width:	1200px
# ---

# %%
#| echo: false

from IPython.display import display_html
def html(text):
    return display_html(text, raw=True)

# %% [markdown]
# # Custom log file analysis
#
# * Create your own log format, and file
# * Parse into a DataFrame
# * Ask any question you want

# %%
import advertools as adv
import pandas as pd
import plotly.express as px
from dash_bootstrap_templates import load_figure_template
load_figure_template('all')

# %% [markdown]
# ## Sample lines from log file

# %%
#| echo: false
with open('sitemap_logs.log', 'rt') as file:
    for i, line in enumerate(file):
        if i in range(100, 2200, 200):
            print(line, end='')
# Out:
# Calling: download_display_sitemap [2021-06-07 03:43:21.901649  2021-06-07 03:43:23.049807] Args: (1, 'https://catalogos365.com/sitemap.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2021-06-12 11:00:36.218844  2021-06-12 11:00:42.400995] Args: (1, 'https://www.bestbettingsites.com/sitemap.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2021-09-19 19:16:27.382222  2021-09-19 19:16:28.991722] Args: (1, 'https://www.sitepen.com/sitemap.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2022-01-09 22:49:44.248476  2022-01-09 22:49:44.736855] Args: (1, 'https://www.herbalife.co.uk/content/herbalifenutrition/emea/en_gb.sitemap.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2022-06-03 13:55:47.990933  2022-06-03 13:55:51.198758] Args: (25, 'https://www.holzprofi24.at/sitemap_index.xml/', [True]) Kwargs: {}
# Calling: download_display_sitemap [2022-09-07 10:36:07.026254  2022-09-07 10:36:10.659670] Args: (3, 'https://www.samco.in/knowledge-center/ht_kb-sitemap.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2022-11-03 20:39:27.063399  2022-11-03 20:39:27.396357] Args: (2, 'https://www.mendix.com/post-sitemap.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2022-12-29 22:50:11.681543  2022-12-29 22:50:17.152572] Args: (1, 'https://www.evolutiontreksperu.com/sitemap_index.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2023-04-10 23:56:21.227138  2023-04-10 23:56:23.770520] Args: (1, 'https://www.agsolve.com.br/sitemap.xml', [True]) Kwargs: {}
# Calling: download_display_sitemap [2024-03-02 23:37:17.432703  2024-03-02 23:37:18.053366] Args: (7, 'https://webforgood.fr/sitemap.xml', [True]) Kwargs: {}

# %% [markdown]
# ## Convert the log file to a parquet file
# * All you need is a regular expression matching the template you created

# %%
#| output: false
log_format_regex = r"\[([^]]+)\].*?(http[^']+).*?(True|\[\])"
adv.logs_to_df(
    log_file='sitemap_logs.log',
    output_file='sitemap_logs.parquet',
    errors_file='sitemap_logs_errors.txt',
    log_format=log_format_regex,
    fields=['start_end', 'url', 'recursive'])
# Out:
# Parsed           2,034 lines.

# %% [markdown]
# ## Minor cleanup

# %%
start_end = pd.read_parquet('sitemap_logs.parquet')['start_end'].str.split('  ', expand=True).rename(columns={0: 'start', 1: 'end'})
logs_df = pd.read_parquet('sitemap_logs.parquet')
logs_df['recursive'] = [True if x == 'True' else False for x in logs_df['recursive']]
logs_df = pd.concat([logs_df, start_end], axis=1)
logs_df['start'] = pd.to_datetime(logs_df['start'])
logs_df['end'] = pd.to_datetime(logs_df['end'])
logs_df['time_diff'] = logs_df['end'].sub(logs_df['start'])
logs_df['seconds'] = logs_df['time_diff'].dt.total_seconds()
logs_df['date'] = logs_df['start'].dt.date

# %% [markdown]
# ## Final DataFrame preview

# %%
logs_df[['url', 'start', 'end', 'time_diff', 'seconds', 'date']]
# Out:
#                                                    url  \
# 0        https://www.foxnews.com/sitemap.xml?type=news
# 1           https://video.foxnews.com/videositemap.xml
# 2           https://video.foxnews.com/videositemap.xml
# 3     https://video.foxnews.com/videositemap.xml?idx=3
# 4     https://www.nytimes.com/sitemaps/new/news.xml.gz
# ...                                                ...
# 2030        https://demandsphere.com/sitemap_index.xml
# 2031                https://www.google.com/sitemap.xml
# 2032        https://demandsphere.com/sitemap_index.xml
# 2033                https://www.ppchero.com/robots.txt
# 2034          https://roofsbydon.com/sitemap_index.xml
#
#                           start                        end  \
# 0    2021-05-10 13:00:24.424540 2021-05-10 13:00:24.594706
# 1    2021-05-10 13:01:18.726869 2021-05-10 13:01:19.327550
# 2    2021-05-10 13:01:48.376871 2021-05-10 13:01:48.478090
# 3    2021-05-10 13:03:04.170089 2021-05-10 13:03:07.091164
# 4    2021-05-10 15:11:05.961278 2021-05-10 15:11:07.405241
# ...                         ...                        ...
# 2030 2024-04-27 17:35:13.665991 2024-04-27 17:35:16.142825
# 2031 2024-04-27 18:15:49.215830 2024-04-27 18:15:53.549334
# 2032 2024-04-27 18:17:19.848497 2024-04-27 18:17:22.209764
# 2033 2024-04-27 19:38:32.857199 2024-04-27 19:38:41.746417
# 2034 2024-04-27 20:06:20.452372 2024-04-27 20:06:25.666170
#
#                   time_diff   seconds        date
# 0    0 days 00:00:00.170166  0.170166  2021-05-10
# 1    0 days 00:00:00.600681  0.600681  2021-05-10
# 2    0 days 00:00:00.101219  0.101219  2021-05-10
# 3    0 days 00:00:02.921075  2.921075  2021-05-10
# 4    0 days 00:00:01.443963  1.443963  2021-05-10
# ...                     ...       ...         ...
# 2030 0 days 00:00:02.476834  2.476834  2024-04-27
# 2031 0 days 00:00:04.333504  4.333504  2024-04-27
# 2032 0 days 00:00:02.361267  2.361267  2024-04-27
# 2033 0 days 00:00:08.889218  8.889218  2024-04-27
# 2034 0 days 00:00:05.213798  5.213798  2024-04-27
#
# [2035 rows x 6 columns]

# %% [markdown]
# #### `start`, `end`: right before/after the function was invoked
#
# #### Unique XML sitemaps processed: 1,206
# #### Total sitemaps processed: 2,035

# %% [markdown]
# ## Sitemap processing time (cumulative) distribution

# %%
#| code-fold: true
fig = px.ecdf(
    logs_df,
    x='seconds',
    lines=False,
    markers=True,
    hover_data=['date', 'recursive'],
    ecdfnorm='percent',
    labels={'seconds': 'Process time (seconds)'},
    height=650,
    opacity=0.8,
    template='slate',
    symbol_sequence=['circle-open'],
    marginal='histogram',
    title='XML Sitemap Downloading and Parsing Time<br><b><a href="https://bit.ly/3gUDXvY">https://adver.tools/xml-sitemaps</a></b>',
    hover_name='url')
fig.layout.yaxis.title = 'Sitemaps taking less time'
fig.layout.yaxis.ticksuffix = '%'
fig.data[0].marker.size = 14
fig.data[0].marker.color = 'snow'
fig.data[1].marker.color = 'snow'
fig
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="8d048af4-0c85-4cbd-86d8-2ca1a6942ece" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8
# %% [markdown]
# * The largest sitemap recorded took around six minutes
# * 99.75% of all sitemaps were processed within two and a half minutes
# * 98% of sitemaps were processed within one minute
# * No need to make any changes to the server

# %% [markdown]
# ## Usage over time

# %%
#| code-fold: true
fig = px.histogram(
    logs_df,
    x='date',
    hover_data=['date', 'recursive'],
    height=650,
    template='slate',
    title='XML Sitemap Usage Over Time<br><b><a href="https://bit.ly/3gUDXvY">https://adver.tools/xml-sitemaps</a></b>',
    hover_name='url')
fig.layout.yaxis.title = 'Number of requests'
fig.data[0].marker.color = 'snow'
fig.add_shape(type='rect', x0='2023-05-01', x1='2023-11-30', y0=0, y1=90, line={'color': 'snow'}, label={'text': '🔴🔴🔴<br>What the hell happened here??<br>😨😨😨'})

fig.add_annotation(x='2021-06-15', y=310, text='🟢🟢🟢<br>SEOFomo newsletter mention.<br>Talk more about it!', showarrow=True)
fig
# Out:
# <div>                            <div id="f15e5f59-a581-40c6-844f-4c1a709817fc" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f15e5f59-a581-40c6-844f-4c1a709817fc")) {                    Plotly.newPlot(                        "f15e5f59-a581-40c6-844f-4c1a709817fc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"date=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"snow","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-10","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-11","2021-05-12","2021-05-12","2021-05-12","2021-05-13","2021-05-13","2021-05-14","2021-05-14","2021-05-14","2021-05-14","2021-05-14","2021-05-15","2021-05-15","2021-05-27","2021-05-28","2021-05-29","2021-05-31","2021-05-31","2021-05-31","2021-06-01","2021-06-01","2021-06-01","2021-06-01","2021-06-01","2021-06-01","2021-06-01","2021-06-02","2021-06-02","2021-06-02","2021-06-02","2021-06-02","2021-06-02","2021-06-02","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-04","2021-06-05","2021-06-05","2021-06-05","2021-06-05","2021-06-05","2021-06-05","2021-06-05","2021-06-05","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-06","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-07","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-08","2021-06-09","2021-06-09","2021-06-10","2021-06-10","2021-06-10","202 ...

# %% [markdown]
# <h3><a href="https://twitter.com/eliasdabbas/status/1401833343369555974">The tweet...</a></h3>
#
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">Honored to have my <a href="https://twitter.com/hashtag/XML?src=hash&amp;ref_src=twsrc%5Etfw">#XML</a> <a href="https://twitter.com/hashtag/Sitemap?src=hash&amp;ref_src=twsrc%5Etfw">#Sitemap</a> analysis tool mentioned in this week&#39;s <a href="https://twitter.com/hashtag/SEOFOMO?src=hash&amp;ref_src=twsrc%5Etfw">#SEOFOMO</a> edition.<br><br>- You might need to disable your ad blocker<br>- There was a timeout issue with large sitemaps, it should be much better now<br><br>Thanks a lot <a href="https://twitter.com/aleyda?ref_src=twsrc%5Etfw">@aleyda</a> you made my week!<a href="https://t.co/v2sVU8T7fE">https://t.co/v2sVU8T7fE</a> <a href="https://t.co/tQCnz0Y6e9">https://t.co/tQCnz0Y6e9</a></p>&mdash; Elias Dabbas (@eliasdabbas) <a href="https://twitter.com/eliasdabbas/status/1401833343369555974?ref_src=twsrc%5Etfw">June 7, 2021</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#
# ## Missing tracking
# For some reason this function wasn't logged between May and November 2023. Analytics shows pageviews were still happening. Not clear if there was a massive unknown bug, or for some reason logging didn't happen.
